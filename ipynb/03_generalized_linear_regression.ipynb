# %% [markdown]
# # Generalized Linear Model

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats
import seaborn as sns

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Contents of this note
# ## 1. Conpects related to generalized linear model
# ### - (1) Exponential Family
# ### - (2) Canonical Form
# ### - (3) Link function and canonical Link Function

# %% [markdown]
# # Part 1 - Conpects related to generalized linear model
# ## (1) [Exponential Family](https://en.wikipedia.org/wiki/Exponential_family)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## (2) Canonical Form
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### [See derivation here](https://github.com/houzhj/Statistics/blob/main/math/03_generalized_linear_model_derivation_01.pdf)

# %% [markdown]
# ![image.png](attachment:image.png)
# ### [See derivation here](https://github.com/houzhj/Statistics/blob/main/math/03_generalized_linear_model_derivation_02.pdf)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## (3) Link function and canonical link function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example: Logistic Regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example: Poisson Regression

# %% [markdown]
# ![image.png](attachment:image.png)
